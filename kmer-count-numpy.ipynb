# %% [markdown]
# # Fully Vectorized K-Mer Counting

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
from SeqRep.dataset_builder import DatasetBuilder, SILVAHeaderParser
builder = DatasetBuilder(SILVAHeaderParser())
dataset = builder.from_fasta(['SILVA_138.1_SSURef_NR99_tax_silva.fasta'])

# %%
from SeqRep.kmers import KMerCounter

counter = KMerCounter(2, jobs=7, chunksize=1000)
data = counter.kmer_sequences(dataset['seqs'].to_numpy())
# Out:
# Generating kmer sequences...
#  22%|██▏       | 111222/510508 [00:05<00:18, 21568.63it/s]ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_175139/2414545800.py", line 4, in <module>
#     counter.kmer_counts(dataset['seqs'].to_numpy())
#   File "/work/08947/nkalidas/ls6/SeqRep/SeqRep/kmers.py", line 44, in kmer_counts
#     kmers = self.kmer_sequences(seqs, quiet=quiet, use_mp=False)
#   File "/work/08947/nkalidas/ls6/SeqRep/SeqRep/kmers.py", line 41, in kmer_sequences
#     return [self.seq_to_kmers(i) for i in it]
#   File "/work/08947/nkalidas/ls6/SeqRep/SeqRep/kmers.py", line 41, in <listcomp>
#     return [self.seq_to_kmers(i) for i in it]
#   File "/work/08947/nkalidas/ls6/SeqRep/SeqRep/kmers.py", line 20, in seq_to_kmers
#     stride = np.lib.stride_tricks.sliding_window_view(binary_converted, 2)
#   File "<__array_function__ internals>", line 5, in sliding_window_view
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/numpy-1.21.2-py3.9-linux-x86_64.egg/numpy/lib/stride_tricks.py", line 312, in sliding_window_view
#     axis = tuple(range(x.ndim))
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/inspect.py", line 1499, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/inspect.py", line 755, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/posixpath.py", line 392, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/posixpath.py", line 426, in _joinrealpath
#     if not islink(newpath):
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/posixpath.py", line 167, in islink
#     st = os.lstat(path)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_175139/2414545800.py", line 4, in <module>
#     counter.kmer_counts(dataset['seqs'].to_numpy())
#   File "/work/08947/nkalidas/ls6/SeqRep/SeqRep/kmers.py", line 44, in kmer_counts
#     kmers = self.kmer_sequences(seqs, quiet=quiet, use_mp=False)
#   File "/work/08947/nkalidas/ls6/SeqRep/SeqRep/kmers.py", line 41, in kmer_sequences
#     return [self.seq_to_kmers(i) for i in it]
#   File "/work/08947/nkalidas/ls6/SeqRep/SeqRep/kmers.py", line 41, in <listcomp>
#     return [self.seq_to_kmers(i) for i in it]
#   File "/work/08947/nkalidas/ls6/SeqRep/SeqRep/kmers.py", line 20, in seq_to_kmers
#     stride = np.lib.stride_tricks.sliding_window_view(binary_converted, 2)
#   File "<__array_function__ internals>", line 5, in sliding_window_view
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/numpy-1.21.2-py3.9-linux-x86_64.egg/numpy/lib/stride_tricks.py", line 312, in sliding_window_view
#     axis = tuple(range(x.ndim))
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3364, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3461, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2066, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/inspect.py", line 1499, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/inspect.py", line 752, in getmodule
#     f = getabsfile(module)
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/inspect.py", line 721, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/inspect.py", line 706, in getsourcefile
#     if os.path.exists(filename):
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_175139/2414545800.py", line 4, in <module>
#     counter.kmer_counts(dataset['seqs'].to_numpy())
#   File "/work/08947/nkalidas/ls6/SeqRep/SeqRep/kmers.py", line 44, in kmer_counts
#     kmers = self.kmer_sequences(seqs, quiet=quiet, use_mp=False)
#   File "/work/08947/nkalidas/ls6/SeqRep/SeqRep/kmers.py", line 41, in kmer_sequences
#     return [self.seq_to_kmers(i) for i in it]
#   File "/work/08947/nkalidas/ls6/SeqRep/SeqRep/kmers.py", line 41, in <listcomp>
#     return [self.seq_to_kmers(i) for i in it]
#   File "/work/08947/nkalidas/ls6/SeqRep/SeqRep/kmers.py", line 20, in seq_to_kmers
#     stride = np.lib.stride_tricks.sliding_window_view(binary_converted, 2)
#   File "<__array_function__ internals>", line 5, in sliding_window_view
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/numpy-1.21.2-py3.9-linux-x86_64.egg/numpy/lib/stride_tricks.py", line 312, in sliding_window_view
#     axis = tuple(range(x.ndim))
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3364, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3461, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2066, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2947, in _run_cell
#     return runner(coro)
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3172, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3383, in run_ast_nodes
#     self.showtraceback()
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2066, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/inspect.py", line 1499, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/inspect.py", line 755, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/posixpath.py", line 392, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/posixpath.py", line 426, in _joinrealpath
#     if not islink(newpath):
#   File "/opt/apps/intel19/python3/3.9.7/lib/python3.9/posixpath.py", line 167, in islink
#     st = os.lstat(path)
# KeyboardInterrupt
